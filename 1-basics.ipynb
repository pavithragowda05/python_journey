# %%
print("hello world")
print("my name is ashwath nagesh belur")
print("i am working svl")

# Comments : comments are peice of text which are ignored by the compiler
# or interpreter. Commentes are useful in making notes/documentation and
# to avoid unwanted to code for execution.

# (ash) is used commenting
# ctrl + / : to comment / uncomment the selected text (toggle action)

#print() : print is used to print the information/message/text/value of
#the variable on the screen/console/terminal.

#to print the message/text, it has be enclsoed with ""/''

#to print the value of the variable then variable name should not be
#enclosed with ""/''

a=10
print("a")
print(a)

# %%
#operators : operators define what activity to be perfromed with given
#set of data.

#mathematical operators :
+
-
*
/ (slash, divsison, gives quoitient)
% (mod, division, gives reminder)
** (power/expoent)
// (floor division)

#relational operators :
< : less than
> : greater than
<= : less than or equal to
>= : greater than or equal to
!= : not equal
== : idential/equality
    
#logial operator :
and : conjunction
or  : disjunction
not : negation
    
#assignment operator :
= : assign
+= : add and assing
-= : sub and assign
/= : divide and assing
*= : multiply and assing
//=:floor divsion and assing

#mathematical operators :
x=100
y=50
a = x+y
b = x-y
c = x/y
d = x%y
e = x**2
print(a)
print(b)
print(c)
print(d)
print(e)

#//floor division : gives quoitient which rounded to nearest
#smallest
i=10
j=6
k = i/j
print(k)
l = i//j
print(l)

# %%
#python is know as dynamic typing language : data type to the varaible is
#automatically assiged by python during runtime, based on data stored in it.

#type() : returns the data type of the variable
#type(variablename)

a=10
b=10.5
c="hello"
d=True
print(type(a))
print(type(b))
print(type(c))
print(type(d))

# %%
#increment and decrement

#increment : increasing the value of the variable

a=10
print(a)
a=a+10
print(a)
a+=10 #assignment operator
print(a)

#decrement : decreasing the value of the variable
b=100
print(b)
b=b-10
print(b)
b-=20
print(b)

# %%
#concatenation : adding of two strings / joining of two strings

a="danush"
b="ha"
c=a+b
print(c)
d=a+" "+b
print(d)

# %%
#type casting : type conversion : converting data from one type to 
#another type (explict conversion)

#datatype(variablename)

x = 100
print(type(x))
print(x)
fx = float(x)
print(fx)
print(type(fx))

y=100.56
print(y)
iy = int(y)
print(iy)

#converting numbers stored as string to int/float

s="10000"
print(type(s))
fs = float(s)
print(fs)
print(type(fs))

i="1000a"
fi = float(i)
#we get an error, as all the characters are not digits

# %%
#input() :accets the data and stores it in a variable at program runtime

#variablename = input("message")

name = input("Enter your name :")
print(f"welcome to svl {name}")

#addition of two numbers using input values :
n1 = input("Enter first number :")
n2 = input("Enter second number :")
tot = n1+n2
print(tot)

#note : by default input stores the data as string

n1 = int(input("Enter first number :"))
n2 = int(input("Enter second number :"))
tot = n1+n2
print(tot)

# %%
#strings : string is collection characters, stored under a name,
#each character is stored in seperate index.
#index starts 0 and it is alway int.

#string extraction / string sclicing : 

#str[index]: retruns the character of the given index

#str[start:end] :returs the characters from the given start index
#till end index -1

#str[:endindex] : when start index is not specified, it will take
#start index as 0 and returns the characters till endindex -1

#str[startindex:] : returns all the characters from given start index
#till end of the string.

#str[-index] : when index is negative it will characters from the 
#end of the string.

mystr = "hello world i am learning python in svl hassan"
print(mystr)

print(mystr[4])
print(mystr[4:15])
print(mystr[:6])
print(mystr[6:])
print(mystr[-1])
print(mystr[-7:-1])

# %%
#str[starindex:endindex:step]
#when we are startindex:endindex is give extraction starts from given
#start index till endindex -1, index is incremented by 1 by default,
#by providing step option we can change the increment/decrement

print(mystr[0:12:2])

#to reverse the given string :
#str[::-1]
print(mystr[::-1])

# %%
#tasks I:
1. accept 3 numbers find the total and average
2. program to convert rupees to dollers
3. to find the area of a triangle 1/2*b*h
4. to find the simple intrest : ptr/100
5. to find the netprice of an item, accept itemprice and discount
   then calcualte net price.
